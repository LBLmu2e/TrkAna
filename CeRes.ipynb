# %%
import sys
extra_paths = ["/home/online1/brownd/mu2e/pyana/TrkAna","/home/online1/brownd/mu2e/pyana/RefAna","/home/online1/brownd/mu2e/pyana/awkward-behaviors"]
for extra_path in extra_paths:
    print("adding path",extra_path)
    if extra_path not in sys.path:
        sys.path.append(extra_path)
print(sys.path)
# Out:
# adding path /home/online1/brownd/mu2e/pyana/TrkAna
# adding path /home/online1/brownd/mu2e/pyana/RefAna
# adding path /home/online1/brownd/mu2e/pyana/awkward-behaviors
# ['/home/online1/brownd/miniconda3/envs/RefAna/lib/python313.zip', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/lib-dynload', '', '/home/online1/brownd/miniconda3/envs/RefAna/lib/python3.13/site-packages', '/home/online1/brownd/mu2e/pyana/TrkAna', '/home/online1/brownd/mu2e/pyana/RefAna', '/home/online1/brownd/mu2e/pyana/awkward-behaviors']

# %%
import CeRes
import SurfaceIds

# %%
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_debug_mc.root"]
#file = ["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack.root" ]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_spack_nofilter.root"]
#file=["/data/HD6/users/brownd/ntp.mu2e.CeEndpointOnSpillTriggered.MDC2020aq_best_v1_3_test.root"]
file = ["/data/HD6/users/brownd/ENDeCalibOnSpill.root"]

# %%
momrange=[80,110]
costrange = [0.5,0.8]

# %%
import ShowTree
#ShowTree.Branches(file[0]+":EventNtuple/ntuple")

# %%
ce = CeRes.CeRes(momrange,costrange,20,1.0e-6,0.8)

# %%
ce.Loop(file)
# Out:
# Processing batch  0 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 1 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 2 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 3 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 4 0 6971 6971 6971 6971 6971 6971
# 1 6971 6971 6971 6971 6971 6971
# 2 6971 6971 6971 6971 6971 6971
# 5 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 6 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 7 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# Found 1 Instances of missing intersections in 6972 tracks
# Missing intersection: TrueTrueFalse eid 1210:59:3887
# 8 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 9 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 10 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 11 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 12 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 13 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 14 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 15 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 16 0 6971 6971 6971 6971 6971 6971
# 1 6971 6971 6971 6971 6971 6971
# 2 6971 6971 6971 6971 6971 6971
# 17 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 18 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 19 0 6972 6972 6972 6972 6972 6972
# 1 6972 6972 6972 6972 6972 6972
# 2 6972 6972 6972 6972 6972 6972
# 20 0 3710 3710 3710 3710 3710 3710
# 1 3710 3710 3710 3710 3710 3710
# 2 3710 3710 3710 3710 3710 3710

# %%
ce.PlotQuality()

# %%
ce.PlotTrackerMomentum()

# %%
ce.PlotTarget()
